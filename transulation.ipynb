# %% [markdown]
# text translation:

# %%
# !pip install translate
# !pip install googletrans==4.0.0rc1

# %%
from translate import Translator
from gtts import gTTS

def translat(a,b):
    change = Translator(to_lang=lang)
    output = change.translate(a)
    return output

if __name__ == "__main__":
    inputt = """
    spartans prepare for glory
    """
    print("ar=arabic,fr=french,ru=russian,etc.")
    lang1 = input("enter code of the lang. to be converted :")
    lang=lang1.lower()

    translat = translat(inputt,lang)
    print("Translated:")
    print(translat)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-cc8e6031c581> in <cell line: 2>()
#       1 from translate import Translator
# ----> 2 from gtts import gTTS
#       3
#       4 def translat(a,b):
#       5     change = Translator(to_lang=lang)
#
# ModuleNotFoundError: No module named 'gtts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# voice:

# %%
# !pip install gTTS

# %%
from gtts import gTTS

txt = "I am optimus prime,from cybertron"

lancode = "en"

gobject = gTTS(text = txt, lang = lancode,slow = False)

gobject.save("/content/gtts.wav")

from IPython.display import Audio

Audio("/content/gtts.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# FINAL :

# %%
# !pip install translate
# !pip install gTTS

# %%
from translate import Translator
from gtts import gTTS

def translat(a,b):
    change = Translator(to_lang=lang)
    output = change.translate(a)
    return output



inputt = """The ancient Tamils lived a nomadic life in hills, forests, and coastal areas. During the medieval period, they transitioned to a settled lifestyle in coastal regions, adopting a sophisticated urban way of life."""
print("ar=arabic,fr=french,ru=russian,etc.")
lang1 = input("enter code of the lang. to be converted :")
lang=lang1.lower()

translat = translat(inputt,lang)

print("")
print("translation for the given is :")
print(translat)
print('')


obj = gTTS(text = translat,
                  lang = lang,
                  slow = False)

obj.save("/content/gtts.wav")



from IPython.display import Audio

Audio("/content/gtts.wav")
# Out:
# ar=arabic,fr=french,ru=russian,etc.
# enter code of the lang. to be converted :ta
#
# translation for the given is :
# பண்டைய தமிழர்கள் மலைகள், காடுகள் மற்றும் கடலோரப் பகுதிகளில் நாடோடி வாழ்க்கை வாழ்ந்தனர். இடைக்காலத்தின் போது, அவர்கள் ஒரு அதிநவீன நகர்ப்புற வாழ்க்கை முறையை பின்பற்றி, கடலோரப் பகுதிகளில் குடியேறிய வாழ்க்கை முறைக்கு மாறினர்.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
